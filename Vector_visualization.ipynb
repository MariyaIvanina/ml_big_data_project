# %% [markdown]
# ## General

# %% [markdown]
# For the analysis of latent vectors, the t-sne algorithm was used. The vectors corresponding to the currency pair are transformed into a two-dimensional space in which they form clusters.
#
# Consider visualization for the 2, 6 and 9 months.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# To prepare data run vector_preparation.sh. Script calculate necessary information for selected periods.

# %% [markdown]
# ## Visualization

# %%
from tsne import VisualizationTSNE

# %%
tsne3 = VisualizationTSNE("F2.csv","tmp_agg_2_names.csv")
tsne3.show_transformed()
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 163 samples in 0.000s...
# [t-SNE] Computed neighbors for 163 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 163 / 163
# [t-SNE] Mean sigma: 0.211248
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.487053
# [t-SNE] KL divergence after 1500 iterations: 0.948032

# %%
tsne6 = VisualizationTSNE("F6.csv","tmp_agg_6_names.csv")
tsne6.show_transformed()
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 163 samples in 0.000s...
# [t-SNE] Computed neighbors for 163 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 163 / 163
# [t-SNE] Mean sigma: 0.211718
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.634193
# [t-SNE] KL divergence after 4000 iterations: 0.929136

# %%
tsne6 = VisualizationTSNE("FBV.csv","tmp_aggBV_names.csv")
tsne6.show_transformed(group_size = 6)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 163 samples in 0.000s...
# [t-SNE] Computed neighbors for 163 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 163 / 163
# [t-SNE] Mean sigma: 0.195905
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.485023
# [t-SNE] KL divergence after 4000 iterations: 0.974339

# %%
tsne9 = VisualizationTSNE("F9.csv","tmp_agg_9_names.csv")
tsne9.show_transformed()
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 155 samples in 0.000s...
# [t-SNE] Computed neighbors for 155 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 155 / 155
# [t-SNE] Mean sigma: 0.212075
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.224365
# [t-SNE] KL divergence after 3000 iterations: 0.929207

# %% [markdown]
# ## Compare 6 and 9

# %% [markdown]
# Some groups have been identified:
#
# BTC-VTC + BTC-TX
#
# BTC-UNB + BTC-XST
#
# USDT-ETH + USDT-BTC + BTC-EMC2 + BTC-GRS
#
# BTC-TRST + BTC-IOP + BTC-NXC + BTC-IOC
#
# BTC-EBST + BTC-TRUST + BTC-ENRG

# %% [markdown]
# <img src="files/6.png">
# <img src="files/9.png">

# %%
tsne9 = VisualizationTSNE("F9.csv","tmp_agg_9_names.csv")
tsne9.show_transformed(group_size=2)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 310 samples in 0.000s...
# [t-SNE] Computed neighbors for 310 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 310 / 310
# [t-SNE] Mean sigma: 0.314888
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.532860
# [t-SNE] KL divergence after 4000 iterations: 0.532436
